# %%
# %%writefile SumaNumeros.java
# Public class SumaNumeros {
#     Public static void main(String[] args)
#         Int num1 =5;
#         Int num2 =10;
#         Int suma = num1 + num2;
#         System.out.println("La suma es: " + suma);
#    }
# }
# Out:
# Writing SumaNumeros.java
